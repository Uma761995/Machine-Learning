# %%
import pickle

# %%
sc=pickle.load(open("scaled_data.sav",'rb'))
preinput=sc.transform([[2000,1000,3000,0,1]])
preinput
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[-1.45320659, -4.76536309, -1.51510487, -0.5       ,  1.30088727]])

# %%
Final_model=pickle.load(open("finalized_model_svr_both.sav",'rb'))
result=Final_model.predict(preinput)
result
# Out:
# array([-1.48405224])

# %%
scy=pickle.load(open("scaled_output.sav",'rb'))
preoutput=scy.inverse_transform([result])
preoutput
# Out:
# array([[46392.13512267]])
